# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import McsPy

# %%
path = '/Users/ovinogradov/Documents/Projects/SCN1A/data/MEA/test/analzyed/2024-08-05T13-59-25McsRecording.h5'

channel_raw_data = McsPy.McsData.RawData(path)

# %%
# channel_raw_data
print(channel_raw_data.comment)
print(channel_raw_data.date)
print(channel_raw_data.clr_date)
print(channel_raw_data.date_in_clr_ticks)
print(channel_raw_data.file_guid)
print(channel_raw_data.mea_name)
print(channel_raw_data.mea_sn)
print(channel_raw_data.mea_layout)
print(channel_raw_data.program_name)
print(channel_raw_data.program_version)
# Out:
# 2024-08-05 13:59:25.161144
# Montag, 5. August 2024
# 638584631651611464
# 7240de1e-946f-4720-9f5a-55a8958f8faf
# 256MEA for MEA2100-256
#
# 256MEA_MEA2100
# Multi Channel Analyzer
# 2.20.15.24102

# %%
def get_axes():
    fig, axs = plt.subplots(16, 16, figsize=(8, 8),dpi=200)
    letters = ['A','B','C','D','E','F','G','H','J','K','L','M','N','O','P','R']
    # Set the labels for each subplot
    labels = [
        [f"{letters[j]}{i + 1}" for j in range(16)] for i in range(16)
    ]

    # Plot circles with text in each subplot
    ax_dict = {}
    for i in range(16):
        for j in range(16):
            ax = axs[i, j]
            ax.axis('off')
#             circle = patches.Circle((0.5, 0.5), radius=0.4,facecolor=[1,1,1],edgecolor='skyblue')#, color='skyblue')
#             ax.add_patch(circle)
            ax_dict[labels[i][j]] =ax
    return fig, ax_dict

# %%
# Out:
# Object `stream.get_channel_in_range` not found.

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# Create a figure
def get_axes():
    fig, axs = plt.subplots(16, 16, figsize=(8, 8),dpi=200)
    letters = ['A','B','C','D','E','F','G','H','J','K','L','M','N','O','P','R']
    # Set the labels for each subplot
    labels = [
        [f"{letters[j]}{i + 1}" for j in range(16)] for i in range(16)
    ]

    # Plot circles with text in each subplot
    ax_dict = {}
    for i in range(16):
        for j in range(16):
            ax = axs[i, j]
            ax.axis('off')
#             circle = patches.Circle((0.5, 0.5), radius=0.4,facecolor=[1,1,1],edgecolor='skyblue')#, color='skyblue')
#             ax.add_patch(circle)
            ax_dict[labels[i][j]] =ax
    return fig, ax_dict

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# Create a figure
fig, axs = plt.subplots(16, 16, figsize=(8, 8),dpi=200)

# Set the labels for each subplot
letters = ['A','B','C','D','E','F','G','H','J','K','L','M','N','O','P','R']
    # Set the labels for each subplot
labels = [
        [f"{letters[j]}{i + 1}" for j in range(16)] for i in range(16)
    ]

values_to_skip =['A1','A16','R1','R16']
# Plot circles with text in each subplot
ax_dic = {}
for i in range(16):
    for j in range(16):
        ax = axs[i, j]
        ax_dic[labels[i][j]] =ax
        if labels[i][j] not in values_to_skip:
    #         Create a circle
#             circle = patches.Circle((0.5, 0.5), radius=0.4, color='skyblue')
            circle = patches.Circle((0.5, 0.5), radius=0.4,facecolor=[1,1,1],edgecolor='skyblue')#, color='skyblue')
            ax.add_patch(circle)
            ax.add_patch(circle)
            # Add text to the center of the circle
            ax.text(0.5, 0.5, labels[i][j], ha='center', va='center', fontsize=10, weight='bold', color='black')
            # Remove axes
            ax.set_xticks([])
            ax.set_yticks([])
            ax.set_xlim(0, 1)
            ax.set_ylim(0, 1)
        ax.axis('off')

# Adjust spacing
# plt.subplots_adjust(wspace=0, hspace=0)

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# Create a figure
fig, axs = plt.subplots(16, 16, figsize=(8, 8),dpi=200)

# Set the labels for each subplot
letters = ['A','B','C','D','E','F','G','H','J','K','L','M','N','O','P','R']
    # Set the labels for each subplot
labels = [
        [f"{letters[j]}{i + 1}" for j in range(16)] for i in range(16)
    ]

values_to_skip =['A1','A16','R1','R16']
# Plot circles with text in each subplot
ax_dic = {}
for i in range(16):
    for j in range(16):
        ax = axs[i, j]
        ax_dic[labels[i][j]] =ax
        if labels[i][j] not in values_to_skip:
    #         Create a circle
#             circle = patches.Circle((0.5, 0.5), radius=0.4, color='skyblue')
            circle = patches.Circle((0.5, 0.5), radius=0.4,facecolor=[1,1,1],edgecolor='skyblue')#, color='skyblue')
            ax.add_patch(circle)
            ax.add_patch(circle)
            # Add text to the center of the circle
            ax.text(0.5, 0.5, labels[i][j], ha='center', va='center', fontsize=10, weight='bold', color='black')
            # Remove axes
            ax.set_xticks([])
            ax.set_yticks([])
            ax.set_xlim(0, 1)
            ax.set_ylim(0, 1)
        ax.axis('off')

# Adjust spacing
# plt.subplots_adjust(wspace=0, hspace=0)

# Display the plot
plt.show()
# Out:
# (0.9, 0.8934343434343435, 0.890909090909091, 1.0)

# %%
list(file.recordings[0].segment_streams[0].segment_entity[1].data_ts)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 list(file.recordings[0].segment_streams[0].segment_entity[1].data_ts)
#
# NameError: name 'file' is not defined

# %%
file.recordings[0].analog_streams[0].info_version
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 file.recordings[0].analog_streams[0].info_version
#
# NameError: name 'file' is not defined

# %%
file.recordings[0].segment_streams[0].segment_entity
# Out:
# {0: <McsPy.McsData.SegmentEntity at 0x3badab3d0>,
#  1: <McsPy.McsData.SegmentEntity at 0x3badb7bd0>,
#  2: <McsPy.McsData.SegmentEntity at 0x3bb06ff90>,
#  3: <McsPy.McsData.SegmentEntity at 0x3bb075010>,
#  4: <McsPy.McsData.SegmentEntity at 0x3bb077190>,
#  6: <McsPy.McsData.SegmentEntity at 0x3bafadcd0>,
#  7: <McsPy.McsData.SegmentEntity at 0x3bb077890>,
#  8: <McsPy.McsData.SegmentEntity at 0x3bb080950>,
#  12: <McsPy.McsData.SegmentEntity at 0x3bb081750>,
#  13: <McsPy.McsData.SegmentEntity at 0x3bb082110>,
#  14: <McsPy.McsData.SegmentEntity at 0x3bb08c490>,
#  17: <McsPy.McsData.SegmentEntity at 0x3bb083c10>,
#  18: <McsPy.McsData.SegmentEntity at 0x3bb08ea50>,
#  19: <McsPy.McsData.SegmentEntity at 0x3bb09f450>,
#  22: <McsPy.McsData.SegmentEntity at 0x3bb0aa190>,
#  23: <McsPy.McsData.SegmentEntity at 0x3bb09f890>,
#  24: <McsPy.McsData.SegmentEntity at 0x3bb09c690>,
#  26: <McsPy.McsData.SegmentEntity at 0x3bb0aeed0>,
#  27: <McsPy.McsData.SegmentEntity at 0x3bb0b7410>,
# ...

# %%
# n_channels = len(file.recordings[0].segment_streams[0].segment_entity)# number of channels with spikes

uids = list(file.recordings[0].segment_streams[0].segment_entity.keys())
na = np.array
st = []
gid = []
unit_label ={}
for uid,unit in enumerate((uids)):
    spikes = na(file.recordings[0].segment_streams[0].segment_entity[unit].data_ts)
    unit_label[file.recordings[0].segment_streams[0].segment_entity[unit].info.label] = unit
    units = [uid]*len(spikes)
#     print(len(spikes[0]))
    st.extend(spikes)
    gid.extend([unit]*len(spikes[0]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 3
#       1 # n_channels = len(file.recordings[0].segment_streams[0].segment_entity)# number of channels with spikes
# ----> 3 uids = list(file.recordings[0].segment_streams[0].segment_entity.keys())
#       4 na = np.array
#       5 st = []
#
# NameError: name 'file' is not defined

# %%
# spikes = file.recordings[0].segment_streams[0].segment_entity[1].data_ts
#

# %%
# file.recordings[0].segment_streams[0].segment_entity[1].data_ts

# %%
st = np.hstack(st)

# %%
gid = np.hstack(gid)

# %%
len(st[10])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[248], line 1
# ----> 1 len(st[10])
#
# TypeError: object of type 'numpy.int64' has no len()

# %%
plt.figure(figsize=(10,3),dpi=300)
plt.plot(st*10e-7,gid,'|k')
sns.despine()
plt.xlabel('Time(s)')
plt.ylabel('Channels')
# Out:
# Text(0, 0.5, 'Channels')

# %%
np.max(st)*10e-6#/100000
# Out:
# 523.74

# %%
st
# Out:
# [array([2533000]),
#  array([2533000]),
#  array([2533000]),
#  array([2533000]),
#  array([2533000]),
#  array([2533000]),
#  array([2533000]),
#  array([2533000]),
#  array([2533000]),
#  array([2533000]),
#  array([2533000]),
#  array([2533000]),
#  array([2533000]),
#  array([2533000]),
#  array([2533000]),
#  array([2533000]),
#  array([2533000]),
#  array([2533000]),
#  array([2533000]),
#  array([2533000]),
#  array([2533000]),
#  array([2533000]),
#  array([2533000]),
#  array([2533000]),
#  array([2533000]),
#  array([2533000]),
#  array([2533000]),
#  array([2533000]),
#  array([2533000]),
#  array([2533000]),
#  array([2533000]),
#  array([2533000]),
#  array([2533000]),
#  array([2533000]),
#  array([2533000]),
#  array([2533000]),
#  array([2533000]),
#  array([2533000]),
#  array([2533000]),
#  array([2533000]),
#  array([2533000]),
#  array([2533000]),
#  array([2533000]),
#  array([2533000]),
#  array([2533000]),
#  array([2533000]),
#  array([2533000]),
# ...

# %%
plt.figure()
plt.plot(gid,st,'.')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
file.recordings[0].segment_streams[0].segment_entity[0].info.label#.segment_entity[1].info.label
# Out:
# 'H16'

# %%
label
# Out:
# 'H10'

# %%
fig,ax = get_axes()
uids = list(file.recordings[0].segment_streams[0].segment_entity.keys())
na = np.array
for uid,unit in enumerate((uids)):
    label = file.recordings[0].segment_streams[0].segment_entity[unit].info.label
#     unit_label[] = unit

    ax[label].plot(file.recordings[0].segment_streams[0].segment_entity[unit].data,'-C5',alpha=0.4);
#     circle = patches.Circle((0.5, 0.5), radius=0.4,facecolor=[1,1,1],edgecolor='skyblue')#, color='skyblue')
#     ax[label].add_patch(circle)
#     ax[label].axis('off')
    ax[label].set_ylim([-3500,1050])

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import LinearSegmentedColormap

# Define the color map
colors = [(0.9, 0.9, 0.9), (.9, 0.25, 0)]  # RGB tuples for pale gray and red
n_bins = 50  # Number of bins for the color map

# Create the custom color map
cmap_name = 'gray_red'
custom_cmap = LinearSegmentedColormap.from_list(cmap_name, colors, N=n_bins)

fig,ax = get_axes()
uids = list(file.recordings[0].segment_streams[0].segment_entity.keys())
na = np.array
for uid,unit in enumerate((uids)):
    label = file.recordings[0].segment_streams[0].segment_entity[unit].info.label
#     unit_label[] = unit
    sc = file.recordings[0].segment_streams[0].segment_entity[unit].data.shape[1]
#     print(sc)
#     ax[label].plot(,'-C5',alpha=0.4);
    circle = patches.Circle((0.5, 0.5), radius=0.4,facecolor=custom_cmap(sc)[:])#, color='skyblue')
    ax[label].add_patch(circle)
    ax[label].text(0.5, 0.5,unit, ha='center', va='center', fontsize=8, weight='bold', color='black',alpha=0.5)

#     ax[label].axis('off')
#     ax[label].set_ylim([-3500,1050])

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import LinearSegmentedColormap

# Define the color map
colors = [(0.9, 0.9, 0.9), (.9, 0.25, 0)]  # RGB tuples for pale gray and red
n_bins = 50  # Number of bins for the color map

# Create the custom color map
cmap_name = 'gray_red'
custom_cmap = LinearSegmentedColormap.from_list(cmap_name, colors, N=n_bins)

# Generate data
data = np.linspace(0, 30, 300).reshape(10, 30)

# Create the plot
fig, ax = plt.subplots()
cax = ax.imshow(data, cmap=custom_cmap, aspect='auto')

# Add a color bar
cbar = fig.colorbar(cax, ticks=[0, 15, 30])
cbar.ax.set_yticklabels(['0', '15', '30'])

plt.show()

# %%
file.recordings[0].segment_streams[0].segment_entity[1].data.shape[1]
# Out:
# 1

# %%
plt.figure(figsize=(10,3),dpi=300)
plt.plot(st*10e-7,gid,'|k')
sns.despine()
plt.xlabel('Time(s)')
plt.ylabel('Channels')
# Out:
# {'A1': <Axes: >,
#  'B1': <Axes: >,
#  'C1': <Axes: >,
#  'D1': <Axes: >,
#  'E1': <Axes: >,
#  'F1': <Axes: >,
#  'G1': <Axes: >,
#  'H1': <Axes: >,
#  'J1': <Axes: >,
#  'K1': <Axes: >,
#  'L1': <Axes: >,
#  'M1': <Axes: >,
#  'N1': <Axes: >,
#  'O1': <Axes: >,
#  'P1': <Axes: >,
#  'R1': <Axes: >,
#  'A2': <Axes: >,
#  'B2': <Axes: >,
#  'C2': <Axes: >,
#  'D2': <Axes: >,
#  'E2': <Axes: >,
#  'F2': <Axes: >,
#  'G2': <Axes: >,
#  'H2': <Axes: >,
#  'J2': <Axes: >,
#  'K2': <Axes: >,
#  'L2': <Axes: >,
#  'M2': <Axes: >,
#  'N2': <Axes: >,
#  'O2': <Axes: >,
#  'P2': <Axes: >,
#  'R2': <Axes: >,
#  'A3': <Axes: >,
#  'B3': <Axes: >,
#  'C3': <Axes: >,
#  'D3': <Axes: >,
#  'E3': <Axes: >,
#  'F3': <Axes: >,
#  'G3': <Axes: >,
#  'H3': <Axes: >,
#  'J3': <Axes: >,
#  'K3': <Axes: >,
#  'L3': <Axes: >,
#  'M3': <Axes: >,
#  'N3': <Axes: >,
#  'O3': <Axes: >,
#  'P3': <Axes: >,
#  'R3': <Axes: >,
#  'A4': <Axes: >,
#  'B4': <Axes: >,
#  'C4': <Axes: >,
#  'D4': <Axes: >,
# ...

# %%
plt.figure()
plt.plot(file.recordings[0].segment_streams[0].segment_entity[3].data,'-k',alpha=0.1);

# %%
file = McsPy.McsData.RawData(path)
electrode_stream = file.recordings[0].analog_streams[0];
# Out:
# Recording_0 <HDF5 group "/Data/Recording_0" (2 members)>
# Stream_0 <HDF5 group "/Data/Recording_0/AnalogStream/Stream_0" (3 members)>
# ChannelData <HDF5 dataset "ChannelData": shape (252, 525000), type "<i4">
# ChannelDataTimeStamps <HDF5 dataset "ChannelDataTimeStamps": shape (1, 3), type "<i8">
# InfoChannel <HDF5 dataset "InfoChannel": shape (252,), type "|V108">

# %%
# Out:
# {0: <Recording label=, AnalogStreams=1, SegmentStreams=1, duration_time=52500000 microsecond>}

# %%
# MCS PyData tools
import McsPy
import McsPy.McsData
from McsPy import ureg, Q_

# %%
def plot_analog_stream_channel(analog_stream, 
                               channel_idxs,ax,
                               from_in_s=0, to_in_s=None, show=True):
    """
    Plots data from a single AnalogStream channel
    
    :param analog_stream: A AnalogStream object
    :param channel_idx: A scalar channel index (0 <= channel_idx < # channels in the AnalogStream)
    :param from_in_s: The start timestamp of the plot (0 <= from_in_s < to_in_s). Default: 0
    :param to_in_s: The end timestamp of the plot (from_in_s < to_in_s <= duration). Default: None (= recording duration)
    :param show: If True (default), the plot is directly created. For further plotting, use show=False
    """
    # extract basic information
    ids = [c.channel_id for c in analog_stream.channel_infos.values()]
#     _ = plt.figure(figsize=(6,2),dpi=200)
    
    for channel_idx in channel_idxs:
#         plt.subplot(16,16,channel_idx+1)
        channel_id = ids[channel_idx]
        channel_info = analog_stream.channel_infos[channel_id]
        sampling_frequency = channel_info.sampling_frequency.magnitude

        # get start and end index
        from_idx = max(0, int(from_in_s * sampling_frequency))
        if to_in_s is None:
            to_idx = analog_stream.channel_data.shape[1]
        else:
            to_idx = min(analog_stream.channel_data.shape[1], int(to_in_s * sampling_frequency))

        # get the timestamps for each sample
        time = analog_stream.get_channel_sample_timestamps(channel_id, from_idx, to_idx)

        # scale time to seconds:
        scale_factor_for_second = Q_(1,time[1]).to(ureg.s).magnitude
        time_in_sec = time[0] * scale_factor_for_second

        # get the signal
        signal = analog_stream.get_channel_in_range(channel_id, from_idx, to_idx)

        # scale signal to µV:
        scale_factor_for_uV = Q_(1,signal[1]).to(ureg.uV).magnitude
        signal_in_uV = signal[0] * scale_factor_for_uV

        # construct the plot

        ax.plot(time_in_sec[:], signal_in_uV[:],'-k',linewidth=0.4)
#         ax.set_ylim([-35,20])
#         _ = plt.xlabel('Time (%s)' % ureg.s)
#         _ = plt.ylabel('Voltage (%s)' % ureg.uV)
#         _ = plt.title('Channel %s' % channel_info.info['Label'])
#         plt.axis('off')

#         if show:
#             plt.show()

    # Then, we can have a look at different channels (feel free to play around with the channel index and the time range):

# %%
#     ids = [c.channel_id for c in electrode_stream.channel_infos.values()]

# %%
plt.figure(figsize=(10,3))
plot_analog_stream_channel(electrode_stream, [31],plt, from_in_s=10., to_in_s=50.5)
plt.xlabel('Time (%s)' % ureg.s)
plt.ylabel('µV')
sns.despine()
#         _ = plt.title('Channel %s' % channel_info.info['Label'])

# %%
plt.close()

# %%
fig,ax = get_axes()
uids = list(file.recordings[0].segment_streams[0].segment_entity.keys())
na = np.array
for uid,unit in enumerate((uids)):
    label = file.recordings[0].segment_streams[0].segment_entity[unit].info.label
#     unit_label[] = unit
    sc = file.recordings[0].segment_streams[0].segment_entity[unit].data.shape[1]
    if sc>30:
        plot_analog_stream_channel(electrode_stream, [unit],ax[label], from_in_s=25., to_in_s=29.5)
#     ax[label].plot(file.recordings[0].segment_streams[0].segment_entity[unit].data,'-C5',alpha=0.4);
#     circle = patches.Circle((0.5, 0.5), radius=0.4,facecolor=[1,1,1],edgecolor='skyblue')#, color='skyblue')
#     ax[label].add_patch(circle)
#     ax[label].axis('off')
#     ax[label].set_ylim([-3500,1050])

# %%
# %matplotlib notebook
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %%
def detect_threshold_crossings(signal, fs, threshold, dead_time):
    """
    Detect threshold crossings in a signal with dead time and return them as an array
    
    The signal transitions from a sample above the threshold to a sample below the threshold for a detection and
    the last detection has to be more than dead_time apart from the current one.
    
    :param signal: The signal as a 1-dimensional numpy array
    :param fs: The sampling frequency in Hz
    :param threshold: The threshold for the signal
    :param dead_time: The dead time in seconds. 
    """
    dead_time_idx = dead_time * fs
    threshold_crossings = np.diff((signal <= threshold).astype(int) > 0).nonzero()[0]
    distance_sufficient = np.insert(np.diff(threshold_crossings) >= dead_time_idx, 0, True)
    while not np.all(distance_sufficient):
        # repeatedly remove all threshold crossings that violate the dead_time
        threshold_crossings = threshold_crossings[distance_sufficient]
        distance_sufficient = np.insert(np.diff(threshold_crossings) >= dead_time_idx, 0, True)
    return threshold_crossings

def get_next_minimum(signal, index, max_samples_to_search):
    """
    Returns the index of the next minimum in the signal after an index
    
    :param signal: The signal as a 1-dimensional numpy array
    :param index: The scalar index 
    :param max_samples_to_search: The number of samples to search for a minimum after the index
    """
    search_end_idx = min(index + max_samples_to_search, signal.shape[0])
    min_idx = np.argmin(signal[index:search_end_idx])
    return index + min_idx

def align_to_minimum(signal, fs, threshold_crossings, search_range):
    """
    Returns the index of the next negative spike peak for all threshold crossings
    
    :param signal: The signal as a 1-dimensional numpy array
    :param fs: The sampling frequency in Hz
    :param threshold_crossings: The array of indices where the signal crossed the detection threshold
    :param search_range: The maximum duration in seconds to search for the minimum after each crossing
    """
    search_end = int(search_range*fs)
    aligned_spikes = [get_next_minimum(signal, t, search_end) for t in threshold_crossings]
    return np.array(aligned_spikes)

# %%
channel_id=3
fs = int(electrode_stream.channel_infos[channel_id].sampling_frequency.magnitude)
crossings = detect_threshold_crossings(signal, fs, spike_threshold, 0.003) # dead time of 3 ms
spks = align_to_minimum(signal, fs, crossings, 0.002) # search range 2 ms
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[74], line 3
#       1 channel_id=3
#       2 fs = int(electrode_stream.channel_infos[channel_id].sampling_frequency.magnitude)
# ----> 3 crossings = detect_threshold_crossings(signal, fs, spike_threshold, 0.003) # dead time of 3 ms
#       4 spks = align_to_minimum(signal, fs, crossings, 0.002)
#
# NameError: name 'signal' is not defined
