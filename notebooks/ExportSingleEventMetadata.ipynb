# %%
# %matplotlib widget
import sys, importlib, os
import McsPy.McsData
import McsPy.McsCMOS
from McsPy import ureg, Q_

# matplotlib.pyplot will be used in these examples to generate the plots visualizing the data
import matplotlib.pyplot as plt
from matplotlib.figure import Figure
from matplotlib.widgets import Slider
import numpy as np
from scipy import signal
from scipy.ndimage import gaussian_filter1d

import seaborn as sns
# import datashader as ds
# import datashader.transfer_functions as tf
import pandas as pd

na = np.array
import scipy.signal
import matplotlib.pyplot as plt

import numpy as np
import scipy.signal
import matplotlib.pyplot as plt
import h5py
import os 
import pickle

# %%
# Overview of all possible recordings 
rec_table = pd.read_csv('/mnt/server_epl/SCN1A/R1648H-analysis/recordings-main2.csv',delimiter=';')

"""
# Get channel mapping
file_name = '/mnt/server_epl/SCN1A/R1648H-export/20-3-25/slice2/2025-03-20T12-08-00McsRecording.h5'
channel_raw_data = McsPy.McsData.RawData(file_name)    
channels = []
channels_dict ={}
for i,ch_n in enumerate(list(channel_raw_data.recordings[0].analog_streams[0].channel_infos.keys())):
    channels.append(channel_raw_data.recordings[0].analog_streams[0].channel_infos[ch_n].label)#.recordings[0].segment_streams[0].segment_entity.keys()
    # channels_dict[int(i)]= channel_raw_data.recordings[0].analog_streams[0].channel_infos[i].label
    channels_dict[channel_raw_data.recordings[0].analog_streams[0].channel_infos[ch_n].label]= int(i)#
"""
# Out:
# /tmp/ipykernel_4372/445860978.py:2: DtypeWarning: Columns (4,15,16,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   rec_table = pd.read_csv('/mnt/server_epl/SCN1A/R1648H-analysis/recordings-main2.csv',delimiter=';')
# "\n# Get channel mapping\nfile_name = '/mnt/server_epl/SCN1A/R1648H-export/20-3-25/slice2/2025-03-20T12-08-00McsRecording.h5'\nchannel_raw_data = McsPy.McsData.RawData(file_name)    \nchannels = []\nchannels_dict ={}\nfor i,ch_n in enumerate(list(channel_raw_data.recordings[0].analog_streams[0].channel_infos.keys())):\n    channels.append(channel_raw_data.recordings[0].analog_streams[0].channel_infos[ch_n].label)#.recordings[0].segment_streams[0].segment_entity.keys()\n    # channels_dict[int(i)]= channel_raw_data.recordings[0].analog_streams[0].channel_infos[i].label\n    channels_dict[channel_raw_data.recordings[0].analog_streams[0].channel_infos[ch_n].label]= int(i)#\n"

# %%
rec_table
# Out:
#          date mouse age  mouseID   slice Valid genotype   Sex  recording  \
# 0    28.10.24       P14        1  slice1  True       wt     ?        1.0
# 1    28.10.24       P14        1  slice1  True       wt     ?        2.0
# 2    28.10.24       P14        1  slice1  True       wt     ?        3.0
# 3    28.10.24       P14        1  slice2  True       wt     ?        1.0
# 4    28.10.24       P14        1  slice2  True       wt     ?        2.0
# ..        ...       ...      ...     ...   ...      ...   ...        ...
# 176   26.3.25       P20       15  slice5   NaN       wt  male        NaN
# 177   26.3.25       P20       15  slice6   NaN       wt  male        1.0
# 178   26.3.25       P20       15  slice6   NaN       wt  male        2.0
# 179   26.3.25       P20       15  slice7   NaN       wt  male        NaN
# 180   26.3.25       P20       15  slice7   NaN       wt  male        NaN
#
#     protocol  duration  ... Unnamed: 16374  Unnamed: 16375 Unnamed: 16376  \
# 0    5-10-10       5.0  ...            NaN             NaN            NaN
# 1    5-10-10      10.0  ...            NaN             NaN            NaN
# 2    5-10-10      10.0  ...            NaN             NaN            NaN
# 3    5-10-10       5.0  ...            NaN             NaN            NaN
# 4    5-10-10      10.0  ...            NaN             NaN            NaN
# ..       ...       ...  ...            ...             ...            ...
# 176    10-40      20.0  ...            NaN             NaN            NaN
# 177  5-10-10       5.0  ...            NaN             NaN            NaN
# 178    10-40       NaN  ...            NaN             NaN            NaN
# 179  5-10-10       5.0  ...            NaN             NaN            NaN
# 180  5-10-10      60.0  ...            NaN             NaN            NaN
#
#     Unnamed: 16377 Unnamed: 16378 Unnamed: 16379 Unnamed: 16380  \
# 0              NaN            NaN            NaN            NaN
# 1              NaN            NaN            NaN            NaN
# 2              NaN            NaN            NaN            NaN
# 3              NaN            NaN            NaN            NaN
# 4              NaN            NaN            NaN            NaN
# ..             ...            ...            ...            ...
# 176            NaN            NaN            NaN            NaN
# 177            NaN            NaN            NaN            NaN
# 178            NaN            NaN            NaN            NaN
# 179            NaN            NaN            NaN            NaN
# 180            NaN            NaN            NaN            NaN
#
#     Unnamed: 16381 Unnamed: 16382 Unnamed: 16383
# 0              NaN            NaN            NaN
# 1              NaN            NaN            NaN
# 2              NaN            NaN            NaN
# 3              NaN            NaN            NaN
# 4              NaN            NaN            NaN
# ..             ...            ...            ...
# 176            NaN            NaN            NaN
# 177            NaN            NaN            NaN
# 178            NaN            NaN            NaN
# 179            NaN            NaN            NaN
# 180            NaN            NaN            NaN
#
# [181 rows x 16384 columns]

# %%
"""
#set img path 
events_all = []
gnt  = []
for i_num in range(157):
    rr = rec_table.iloc[i_num]
    region = 'ctx'
    rr.date
    rr.slice
    rr.protocol
    rec_n = rr.recording
    if rec_n>1:
        try:
            file_name = rec_table.iloc[i_num].file_name
            detected_events = pd.read_csv('data/R1648H/detected_events/'+'detected_events_'+str(region)+'_'+file_name)
            durs = detected_events['intervals_end']-detected_events['intervals_start']
            events_all.extend(durs)
            gnt.extend([rr.genotype]*len(detected_events))
            
        except:
            continue



df = pd.DataFrame({'events_dur':events_all,'genotype':gnt})


plt.figure()
sns.pointplot(x='genotype',y='events_dur',data=df)

print(np.sum(na(gnt)=='mut') )
print(np.sum(na(gnt)=='wt'))

plt.figure()
plt.plot(na(events_all)[na(gnt)=='mut'])
plt.plot(na(events_all)[na(gnt)=='wt'])

plt.figure()
plt.plot(events_all)
plt.axhline(11)

# np.sum(na(events_all)>10)
na(gnt)[na(events_all)>10]
"""

# %%
all_rates = []

for i_num in range(180):
    try:
        file_name = rec_table.iloc[i_num].file_name
        # print(file_name)
        # detected_events = pd.read_csv('data/R1648H/detected_events/'+'detected_events_'+str(region)+'_'+file_name)
        # print(detected_events)
        from datetime import datetime
        path = rec_table.iloc[i_num].path.replace('\\','/')
        file_name = rec_table.iloc[i_num].file_name
        genotype = rec_table.iloc[i_num].genotype
        #print(genotype)
        
        print('Protocol',rec_table.iloc[i_num].protocol,'Recording',rec_table.iloc[i_num].recording)
        os.path.join(path,file_name)
        slice_ =path.split('/')[-1]
        date =path.split('/')[0]
        dt = datetime.strptime(date, '%d-%m-%y')
        date = dt.strftime('%d-%m-%y')
        
        filt_file_name = 'R1648H_'+date+'_'+slice_+'_'+file_name+'.h5_filtered.h5'
        filt_path = '/mnt/server_epl/SCN1A/R1648H_filt'
        target_file = os.path.join(filt_path,filt_file_name).replace('\\','/')
        print(target_file)

        """
        detection_path = '/mnt/server_epl/SCN1A/R1648/'+rec_table.iloc[i_num].image_path + '/labeled_electrodes.csv'
        detection_path =detection_path.replace('\\','/')
        ch_detection =pd.read_csv(detection_path)
        regions= na(ch_detection['region'])
        ch_labels = na(ch_detection['e_label'])
        valid_channels = [channels_dict[ch] for ch in ch_labels]
# Protocol 5-10-10 Recording 3.0
# /mnt/server_epl/SCN1A/R1648H_filt/R1648H_21-03-25_slice1_2025-03-21T11-09-44McsRecording.h5_filtered.h5
# hello!
# 1600
# Protocol 5-10-10 Recording 1.0
# /mnt/server_epl/SCN1A/R1648H_filt/R1648H_21-03-25_slice2_2025-03-21T11-22-54McsRecording.h5_filtered.h5
# hello!
# 1600
# Protocol extra Recording 2.0
# /mnt/server_epl/SCN1A/R1648H_filt/R1648H_21-03-25_slice2_2025-03-21T11-33-19McsRecording.h5_filtered.h5
# hello!
# 1600
# Protocol 5-10-10 Recording 3.0
# /mnt/server_epl/SCN1A/R1648H_filt/R1648H_21-03-25_slice2_2025-03-21T11-41-42McsRecording.h5_filtered.h5
# hello!
# 1600
# Protocol 5-10-10 Recording 4.0
# /mnt/server_epl/SCN1A/R1648H_filt/R1648H_21-03-25_slice2_2025-03-21T12-02-22McsRecording.h5_filtered.h5
# hello!
# 1600
# Protocol 5-10-10 Recording 1.0
# /mnt/server_epl/SCN1A/R1648H_filt/R1648H_21-03-25_slice3_2025-03-21T12-20-48McsRecording.h5_filtered.h5
# hello!
# 1600
# Protocol 20-30 Recording nan
# /mnt/server_epl/SCN1A/R1648H_filt/R1648H_21-03-25_slice3_2025-03-21T12-42-43McsRecording.h5_filtered.h5
# hello!
# 1600
# Protocol 5-10-10 Recording 1.0
# /mnt/server_epl/SCN1A/R1648H_filt/R1648H_21-03-25_slice4_2025-03-21T13-20-16McsRecording.h5_filtered.h5
# hello!
# 1600
# Protocol 10-40 Recording 2.0
# /mnt/server_epl/SCN1A/R1648H_filt/R1648H_21-03-25_slice4_2025-03-21T13-29-38McsRecording.h5_filtered.h5
# hello!
# 1600
# Protocol 5-10-10 Recording 1.0
# /mnt/server_epl/SCN1A/R1648H_filt/R1648H_21-03-25_slice5_2025-03-21T14-11-06McsRecording.h5_filtered.h5
# hello!
# 1600
# Protocol 10-40 Recording 2.0
# /mnt/server_epl/SCN1A/R1648H_filt/R1648H_21-03-25_slice5_2025-03-21T14-18-05McsRecording.h5_filtered.h5
# hello!
# 1600
# Protocol 5-10-10 Recording 1.0
# /mnt/server_epl/SCN1A/R1648H_filt/R1648H_21-03-25_slice6_2025-03-21T14-42-46McsRecording.h5_filtered.h5
# hello!
# 1600
# Protocol 10-40 Recording 2.0
# /mnt/server_epl/SCN1A/R1648H_filt/R1648H_21-03-25_slice6_2025-03-21T14-52-28McsRecording.h5_filtered.h5
# hello!
# 800
# Protocol 5-10-10 Recording 1.0
# /mnt/server_epl/SCN1A/R1648H_filt/R1648H_25-03-25_slice1_2025-03-25T10-53-17McsRecording.h5_filtered.h5
# hello!
# 1600
# Protocol 10-40 Recording 2.0
# /mnt/server_epl/SCN1A/R1648H_filt/R1648H_25-03-25_slice1_2025-03-25T11-07-24McsRecording.h5_filtered.h5
# hello!
# 1600
# Protocol 5-10-10 Recording 1.0
# /mnt/server_epl/SCN1A/R1648H_filt/R1648H_25-03-25_slice2_2025-03-25T12-19-52McsRecording.h5_filtered.h5
# hello!
# 1600
# Protocol 10-40 Recording 2.0
# /mnt/server_epl/SCN1A/R1648H_filt/R1648H_25-03-25_slice2_2025-03-25T12-30-22McsRecording.h5_filtered.h5
# hello!
# 1600
# Protocol 5-10-10 Recording 1.0
# /mnt/server_epl/SCN1A/R1648H_filt/R1648H_25-03-25_slice3_2025-03-25T12-47-22McsRecording.h5_filtered.h5
# hello!
# 1600
# Protocol 5-10-10 Recording 1.0
# /mnt/server_epl/SCN1A/R1648H_filt/R1648H_25-03-25_slice4_2025-03-25T13-15-56McsRecording.h5_filtered.h5
# hello!
# 1600
# Protocol 10-40 Recording 2.0
# /mnt/server_epl/SCN1A/R1648H_filt/R1648H_25-03-25_slice4_2025-03-25T13-27-56McsRecording.h5_filtered.h5
# hello!
# 1600
# Protocol 5-10-10 Recording 1.0
# /mnt/server_epl/SCN1A/R1648H_filt/R1648H_25-03-25_slice5_2025-03-25T14-33-58McsRecording.h5_filtered.h5
# hello!
# 1600
# Protocol 10-40 Recording 2.0
# /mnt/server_epl/SCN1A/R1648H_filt/R1648H_25-03-25_slice5_2025-03-25T14-43-18McsRecording.h5_filtered.h5
# hello!
# 1600
# Protocol 5-10-10 Recording 1.0
# /mnt/server_epl/SCN1A/R1648H_filt/R1648H_26-03-25_slice1_2025-03-26T10-37-19McsRecording.h5_filtered.h5
# hello!
# 1600
# Protocol 10-40 Recording 2.0
# /mnt/server_epl/SCN1A/R1648H_filt/R1648H_26-03-25_slice1_2025-03-26T10-46-39McsRecording.h5_filtered.h5
# hello!
# 1600
# Protocol 5-10-10 Recording 1.0
# /mnt/server_epl/SCN1A/R1648H_filt/R1648H_26-03-25_slice2_2025-03-26T12-20-02McsRecording.h5_filtered.h5
# hello!
# 1600
# Protocol 10-40 Recording 2.0
# /mnt/server_epl/SCN1A/R1648H_filt/R1648H_26-03-25_slice2_2025-03-26T12-35-24McsRecording.h5_filtered.h5
# hello!
# 1600
# Protocol 5-10-10 Recording 1.0
# /mnt/server_epl/SCN1A/R1648H_filt/R1648H_26-03-25_slice3_2025-03-26T13-30-35McsRecording.h5_filtered.h5
# hello!
# 1600
# Protocol 10-40 Recording 2.0
# /mnt/server_epl/SCN1A/R1648H_filt/R1648H_26-03-25_slice3_2025-03-26T13-41-55McsRecording.h5_filtered.h5
# hello!
# 1600
# Protocol 5-10-10 Recording 1.0
# /mnt/server_epl/SCN1A/R1648H_filt/R1648H_26-03-25_slice4_2025-03-26T14-36-14McsRecording.h5_filtered.h5
# hello!
# 1600
# Protocol 10-40 Recording 2.0
# /mnt/server_epl/SCN1A/R1648H_filt/R1648H_26-03-25_slice4_2025-03-26T14-49-20McsRecording.h5_filtered.h5
# hello!
# 1600
# Protocol 5-10-10 Recording 1.0
# /mnt/server_epl/SCN1A/R1648H_filt/R1648H_26-03-25_slice5_2025-03-26T15-20-01McsRecording.h5_filtered.h5
# hello!
# 1600
# Protocol 10-40 Recording nan
# /mnt/server_epl/SCN1A/R1648H_filt/R1648H_26-03-25_slice5_2025-03-26T15-29-35McsRecording.h5_filtered.h5
# hello!
# 1600
# Protocol 5-10-10 Recording 1.0
# /mnt/server_epl/SCN1A/R1648H_filt/R1648H_26-03-25_slice6_2025-03-26T15-45-41McsRecording.h5_filtered.h5
# hello!
# 1600
# Protocol 10-40 Recording 2.0
# /mnt/server_epl/SCN1A/R1648H_filt/R1648H_26-03-25_slice6_2025-03-26T15-54-35McsRecording.h5_filtered.h5
# hello!
# 1600
# Protocol 5-10-10 Recording nan
# /mnt/server_epl/SCN1A/R1648H_filt/R1648H_26-03-25_slice7_2025-03-26T16-19-27McsRecording.h5_filtered.h5
# hello!
# 1600

# %%
x = np.load("data/sampling_rates.npy")

print(x)
# Out:
# [1600 1600 1600 1600 1600 1600 1600 1600 1600 1600 1600 1600 1600 1600
#  1600 1600 1600 1600 1600 1600 1600 1600 1600 1600 1600 1600 1600 1600
#  1600 1600 1600 1600 1600 1600 1600 1600 1600 1600 1600 1600 1600 1600
#  1600 1600 1600 1600 1600 1600 1600 1600 1600 1600 1600 1600 1600 1600
#  1600 1600 1600 1600 1600 1600 1600 1600 1600 1600 1600 1600 1600 1600
#  1600 1600 1600 1600 1600 1600 1600 1600 1600 1600 1600 1600 1600 1600
#  1600 1600 1600 1600 1600 1600 1600 1600 1600 1600 1600 1600 1600 1600
#  1600 1600 1600 1600 1600 1600 1600 1600 1600 1600 1600 1600 1600 1600
#  1600 1600 1600 1600 1600 1600 1600 1600 1600 1600 1600 1600 1600 1600
#  1600 1600 1600 1600 1600 1600 1600 1600 1600 1600 1600 1600 1600 1600
#  1600 1600 1600 1600 1600 1600  800 1600 1600 1600 1600 1600 1600 1600
#  1600 1600 1600 1600 1600 1600 1600 1600 1600 1600 1600 1600 1600 1600
#  1600]

# %%
"""
# name = genotype+'_'+str(region)+'_'+file_name
with open('data/exported_events/%s.pickle'%name, 'rb') as f:
    data = pickle.load(f)

len(data)

np.savez_compressed('data/exported_events/%s'%name, *all_events)
# name = genotype+str(region)+'_'+file_name
# with open('data/exported_events/%s.pickle'%name, 'wb') as f:
#     pickle.dump(all_events, f)

data = np.load('data/exported_events/%s.pickle.npz'%name)

data['arr_0'].shape

plt.figure()
plt.plot(np.arange(0,len(all_events[14]))*(1/subsampling_rate),all_events[14]);

plt.figure()
y= all_events[13]#/np.max(filt[::subsplot,regions==region],0)#+np.arange(0,np.sum(regions==region))*300
y= y+np.arange(0,y.shape[1])*1000
plt.plot(y,alpha=0.3);

plt.plot(all_events[13]);

durs = detected_events['intervals_end']-detected_events['intervals_start']

np.where(durs>10)[0]

plt.figure()
plt.plot(event);


s/

detected_events['duration']= detected_events['intervals_end']-detected_events['intervals_start']

plt.plot(detected_events['duration']

region = 'ctx'
plt.figure(figsize=(10,3))
subsplot = 1
plt.plot(np.arange(0,len(filt[::subsplot]))*(1/(subsampling_rate/subsplot)),filt[::subsplot,regions==region],alpha=0.3)
plt.show()
try:
    detected_events = pd.read_csv('../data/R1648H/detected_events/'+'detected_events_'+str(region)+'_'+file_name)
    [plt.axvspan(na(detected_events.iloc[i].intervals_start),na(detected_events.iloc[i].intervals_end),alpha=0.2) for i in range(len(detected_events))];
except:
    print('Not detected yet')
"""
